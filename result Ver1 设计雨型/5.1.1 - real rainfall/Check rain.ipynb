# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = open('./sim/1Astlingen_Erft1.txt',"r")   #设置文件对象
rain = f.read().split('\n')     #将txt文件的所有内容读入到字符串str中
f.close()

# %%
print(rain[0])
# Out:
# 01/01/2000  00:00:00     0.00

# %%
raindata=[]
for r in rain:
    raindata.append(r.split(' ')[-1])

# %%
plt.plot(raindata)

# %%
print(len(raindata))
# Out:
# 1051201
