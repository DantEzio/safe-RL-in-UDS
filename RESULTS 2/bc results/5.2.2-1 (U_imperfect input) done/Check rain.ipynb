# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rain=np.loadtxt('./sim/trainRainFile.txt',delimiter=',')/2.2#读取测试降雨数据
print(rain.shape)
# Out:
# (200, 240)

# %%
for i in range(10):
    plt.plot(rain[i,:])
