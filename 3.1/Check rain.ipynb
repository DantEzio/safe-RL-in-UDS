# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#rain=np.loadtxt('./sim/trainRainFile.txt',delimiter=',')/2.2#读取测试降雨数据
rain=np.loadtxt('./sim/A_real_raindata.txt',delimiter=' ')#读取训练降雨数据
print(rain.shape)
# Out:
# (26, 288)

# %%
for i in range(10):
    plt.plot(rain[i,:])
